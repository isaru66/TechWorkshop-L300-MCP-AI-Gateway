# %% [markdown]
# # APIM ❤️ FinOps
#
# ## FinOps Framework lab
# ![flow](../../media/common/finops-framework.gif)
#
# This playground leverages the [FinOps Framework](https://www.finops.org/framework/) and Azure API Management to control AI costs. It uses the [token limit](https://learn.microsoft.com/en-us/azure/api-management/azure-openai-token-limit-policy) policy for each [product](https://learn.microsoft.com/en-us/azure/api-management/api-management-howto-add-products?tabs=azure-portal&pivots=interactive) and integrates [Azure Monitor alerts](https://learn.microsoft.com/en-us/azure/azure-monitor/alerts/alerts-overview) with [Logic Apps](https://learn.microsoft.com/en-us/azure/azure-monitor/alerts/alerts-logic-apps?tabs=send-email) to automatically disable APIM [subscriptions](https://learn.microsoft.com/en-us/azure/api-management/api-management-subscriptions) that exceed cost quotas.
#
# ### Result
# ![result](result.png)
#
# ### Prerequisites
#
# - [Python 3.12 or later version](https://www.python.org/) installed
# - [VS Code](https://code.visualstudio.com/) installed with the [Jupyter notebook extension](https://marketplace.visualstudio.com/items?itemName=ms-toolsai.jupyter) enabled
# - [Python environment](https://code.visualstudio.com/docs/python/environments#_creating-environments) with the [requirements.txt](../../requirements.txt) or run `pip install -r requirements.txt` in your terminal
# - [An Azure Subscription](https://azure.microsoft.com/free/) with [Contributor](https://learn.microsoft.com/en-us/azure/role-based-access-control/built-in-roles/privileged#contributor) + [RBAC Administrator](https://learn.microsoft.com/en-us/azure/role-based-access-control/built-in-roles/privileged#role-based-access-control-administrator) or [Owner](https://learn.microsoft.com/en-us/azure/role-based-access-control/built-in-roles/privileged#owner) roles
# - [Azure CLI](https://learn.microsoft.com/cli/azure/install-azure-cli) installed and [Signed into your Azure subscription](https://learn.microsoft.com/cli/azure/authenticate-azure-cli-interactively)
#
# ▶️ Click `Run All` to execute all steps sequentially, or execute them `Step by Step`...

# %% [markdown]
# <a id='0'></a>
# ### 0️⃣ Initialize notebook variables
#
# - Resources will be suffixed by a unique string based on your subscription id.
# - Adjust the location parameters according your preferences and on the [product availability by Azure region.](https://azure.microsoft.com/explore/global-infrastructure/products-by-region/?cdn=disable&products=cognitive-services,api-management)
# - Adjust the OpenAI model and version according the [availability by region.](https://learn.microsoft.com/azure/ai-services/openai/concepts/models)

# %%
import os, sys, json
sys.path.insert(1, './shared')  # add the shared directory to the Python path
import utils

deployment_name = os.path.basename(os.path.dirname(globals()['__vsc_ipynb_file__']))
resource_group_name = f"lab-{deployment_name}" # change the name to match your naming style
resource_group_location = "westeurope"

aiservices_config = [{"name": "foundry1", "location": "swedencentral"}]

models_config = [ { "name": "gpt-5.2-chat", "publisher": "OpenAI", "version": "2025-04-14", "sku": "GlobalStandard", "capacity": 200, "inputTokensMeterSku": "GPT 5.2 chat inp Gl", "outputTokensMeterSku": "GPT 5.2 chat opt Gl" },
                 { "name": "gpt-5.2", "publisher": "OpenAI", "version": "2025-04-14", "sku": "GlobalStandard", "capacity": 200, "inputTokensMeterSku": "GPT 5.2 inp Gl", "outputTokensMeterSku": "GPT 5.2 opt Gl" },
                 { "name": "gpt-5-mini", "publisher": "OpenAI", "version": "2025-04-14", "sku": "GlobalStandard", "capacity": 200, "inputTokensMeterSku": "GPT 5 Mini Inpt Glbl", "outputTokensMeterSku": "GPT 5 Mini outpt Glbl" },
                 { "name": "gpt-5-nano", "publisher": "OpenAI", "version": "2025-04-14", "sku": "GlobalStandard", "capacity": 200, "inputTokensMeterSku": "GPT 5 Nano Inpt Glbl", "outputTokensMeterSku": "GPT 5 Nano outpt Glbl" },
                 { "name": "gpt-4.1-mini", "publisher": "OpenAI", "version": "2025-04-14", "sku": "GlobalStandard", "capacity": 200, "inputTokensMeterSku": "gpt 4.1 mini Inp glbl", "outputTokensMeterSku": "gpt 4.1 mini Outp glbl" }, 
                { "name": "gpt-4.1", "publisher": "OpenAI", "version": "2025-04-14", "sku": "GlobalStandard", "capacity": 200, "inputTokensMeterSku": "gpt 4.1 Inp glbl", "outputTokensMeterSku": "gpt 4.1 Outp glbl" },
                { "name": "DeepSeek-V3.2", "publisher": "DeepSeek",  "version": "1", "sku": "GlobalStandard", "capacity": 100, "inputTokensMeterSku": "V3.2 Inp glbl", "outputTokensMeterSku": "V3.2 Outp glbl"} ]

apim_sku = 'Basicv2'
apim_products_config = [{"name": "platinum", "displayName": "Platinum Product", "tpm": 2000, "tokenQuota": 1000000, "tokenQuotaPeriod": "Monthly", "costQuota": 15 },
                    {"name": "gold", "displayName": "Gold Product", "tpm": 1000, "tokenQuota": 1000000, "tokenQuotaPeriod": "Monthly", "costQuota": 10}, 
                    {"name": "silver", "displayName": "Silver Product", "tpm": 500, "tokenQuota": 1000000, "tokenQuotaPeriod": "Monthly", "costQuota": 5}]
apim_users_config = [ ]
apim_subscriptions_config = [{"name": "subscription1", "displayName": "Subscription 1", "product": "platinum" },
                    {"name": "subscription2", "displayName": "Subscription 2", "product": "gold" },
                    {"name": "subscription3", "displayName": "Subscription 3", "product": "silver" },
                     {"name": "subscription4", "displayName": "Subscription 4", "product": "silver" } ]

inference_api_path = "inference"  # path to the inference API in the APIM service
inference_api_type = "AzureOpenAI"  # options: AzureOpenAI, AzureAI, OpenAI, PassThrough
inference_api_version = "2025-03-01-preview"
foundry_project_name = deployment_name

currency_code = 'USD'

utils.print_ok('Notebook initialized')
# Out:
# ✅ Notebook initialized ⌚ 00:44:23.693694

# %% [markdown]
# <a id='1'></a>
# ### 1️⃣ Verify the Azure CLI and the connected Azure subscription
#
# The following commands ensure that you have the latest version of the Azure CLI and that the Azure CLI is connected to your Azure subscription.

# %%
output = utils.run("az account show", "Retrieved az account", "Failed to get the current az account")

if output.success and output.json_data:
    current_user = output.json_data['user']['name']
    tenant_id = output.json_data['tenantId']
    subscription_id = output.json_data['id']

    utils.print_info(f"Current user: {current_user}")
    utils.print_info(f"Tenant ID: {tenant_id}")
    utils.print_info(f"Subscription ID: {subscription_id}")

output = utils.run("az ad signed-in-user show", "Retrieved az ad signed-in-user", "Failed to get az ad signed-in-user")
if output.success and output.json_data:
    current_user_object_id = output.json_data['id']
# Out:
# ⚙️ Running: az account show
# ✅ Retrieved az account ⌚ 00:42:21.330566 :1s]
# 👉🏽 Current user: isarar@microsoft.com
# 👉🏽 Tenant ID: ddcbdc96-6162-4d91-bb0d-066343049ce1
# 👉🏽 Subscription ID: 79e1d757-ecdb-4dc3-b0b4-035bac76053d
# ⚙️ Running: az ad signed-in-user show
# ✅ Retrieved az ad signed-in-user ⌚ 00:42:26.326037 :4s]

# %% [markdown]
# <a id='2'></a>
# ### 2️⃣ Verify Azure Developer CLI (azd) deployment
#
# This lab uses [Azure Developer CLI (azd)](https://learn.microsoft.com/azure/developer/azure-developer-cli/overview) to deploy resources.
#
# ⚠️ Ensure you have already run `azd up` from the repository root before continuing with this notebook.

# %%
# Verify azd deployment exists
output = utils.run("azd env get-values", "Retrieved azd environment", "Failed to get azd environment. Please run 'azd up' first.")

if output.success:
    utils.print_ok("Azure Developer CLI environment is configured")
else:
    utils.print_error("Please run 'azd up' from the repository root to deploy resources before continuing")
# Out:
# ⚙️ Running: azd env get-values
# ✅ Retrieved azd environment ⌚ 00:42:26.763480 :0s]
# ✅ Azure Developer CLI environment is configured ⌚ 00:42:26.764024

# %% [markdown]
# <a id='3'></a>
# ### 3️⃣ Get the environment values from azd
#
# Retrieve the required outputs from the Azure Developer CLI environment.

# %%
# Get all environment values from azd
output = utils.run("azd env get-values", "Retrieved azd environment values", "Failed to get azd environment values")

if output.success:
    env_vars = {}
    for line in output.text.splitlines():
        if '=' in line:
            key, value = line.split('=', 1)
            env_vars[key] = value.strip('"')
    
    # Extract required values (using actual azd variable names)
    apim_resource_gateway_url = env_vars.get('apim_gateway_url')
    pricing_dcr_endpoint = env_vars.get('pricingDCREndpoint')
    pricing_dcr_immutable_id = env_vars.get('pricingDCRImmutableId')
    pricing_dcr_stream = env_vars.get('pricingDCRStream')
    apim_service_name = env_vars.get('apim_service_name')
    subscription_quota_dcr_endpoint = env_vars.get('subscriptionQuotaDCREndpoint')
    subscription_quota_dcr_immutable_id = env_vars.get('subscriptionQuotaDCRImmutableId')
    subscription_quota_dcr_stream = env_vars.get('subscriptionQuotaDCRStream')
    
    # Parse APIM subscriptions JSON if available
    apim_subscriptions_json = env_vars.get('apim_subscriptions')
    if apim_subscriptions_json:
        try:
            apim_subscriptions = json.loads(apim_subscriptions_json.replace("'", '"'))
            for subscription in apim_subscriptions:
                subscription_name = subscription['name']
                subscription_key = subscription['key']
                utils.print_info(f"Subscription Name: {subscription_name}")
                utils.print_info(f"Subscription Key: ****{subscription_key[-4:]}")
        except Exception as e:
            utils.print_warning(f"Could not parse APIM subscriptions: {e}")
    
    # Display retrieved values
    utils.print_info(f"APIM Gateway URL: {apim_resource_gateway_url}")
    utils.print_info(f"APIM Service Name: {apim_service_name}")
    utils.print_info(f"Pricing DCR Endpoint: {pricing_dcr_endpoint}")
    utils.print_info(f"Pricing DCR Immutable ID: {pricing_dcr_immutable_id}")
    utils.print_info(f"Pricing DCR Stream: {pricing_dcr_stream}")
    utils.print_info(f"Subscription Quota DCR Endpoint: {subscription_quota_dcr_endpoint}")
    utils.print_info(f"Subscription Quota DCR Immutable ID: {subscription_quota_dcr_immutable_id}")
    utils.print_info(f"Subscription Quota DCR Stream: {subscription_quota_dcr_stream}")
# Out:
# ⚙️ Running: azd env get-values
# ✅ Retrieved azd environment values ⌚ 00:54:11.730686 :0s]
# 👉🏽 APIM Gateway URL: https://apim-kx3lo3f7gbwya.azure-api.net
# 👉🏽 APIM Service Name: apim-kx3lo3f7gbwya
# 👉🏽 Pricing DCR Endpoint: https://dcr-pricing-kx3lo3f7gbwya-mkca-swedencentral.logs.z1.ingest.monitor.azure.com
# 👉🏽 Pricing DCR Immutable ID: dcr-e7f2bc1bf7ba4f9db4cc9851967993d2
# 👉🏽 Pricing DCR Stream: Custom-Json-PRICING_CL
# 👉🏽 Subscription Quota DCR Endpoint: https://dcr-quota-kx3lo3f7gbwya-uspl-swedencentral.logs.z1.ingest.monitor.azure.com
# 👉🏽 Subscription Quota DCR Immutable ID: dcr-aa485b86ad2d48df8d56365c827817d9
# 👉🏽 Subscription Quota DCR Stream: Custom-Json-SUBSCRIPTION_QUOTA_CL

# %% [markdown]
# <a id='pricing'></a>
# ### 🔍 Display retail pricing info based on the [pricing API](https://learn.microsoft.com/en-us/rest/api/cost-management/retail-prices/azure-retail-prices)

# %%
import requests
from tabulate import tabulate 

def build_pricing_table(json_data, table_data):
    for item in json_data['Items']:
        meter = item['meterName']
        table_data.append([item['armRegionName'], item['armSkuName'], item['retailPrice']*1000])

table_data = []
table_data.append(['Region', 'SKU', 'Retail Price'])
for aiservice in aiservices_config:
    aiservice_resource_location = aiservice['location']    
    prices = requests.get(f"https://prices.azure.com/api/retail/prices?currencyCode='{currency_code}'&$filter=serviceName eq 'Foundry Models' and unitOfMeasure eq '1K' and armRegionName eq '{aiservice_resource_location}'")
    if prices.status_code == 200:
        prices_json = prices.json()
        build_pricing_table(prices_json, table_data)
    print(tabulate(table_data, headers='firstrow', tablefmt='psql'))
# Out:
# +---------------+---------------------------------------------+----------------+
# | Region        | SKU                                         |   Retail Price |
# |---------------+---------------------------------------------+----------------|
# | swedencentral | o3 mini 0131 Batch Outp Data Zone           |          2.42  |
# | swedencentral | gpt 4.1 nano cached Inp glbl                |          0.025 |
# | swedencentral | gpt4omini-rt-aud1217 Outp regnl             |         24.2   |
# | swedencentral | gpt-4o-aud-0603-txt Inp DZone               |          2.75  |
# | swedencentral | gpt-4o-rt-aud-0603 Outp glbl                |         80     |
# | swedencentral | Phi-4-reasoning-Output                      |          0.5   |
# | swedencentral | o1-pro Inp regnl                            |        181.5   |
# | swedencentral | o3 0416 Batch Outp glbl                     |          4     |
# | swedencentral | gpt 4.1 Inp regnl                           |          2.42  |
# | swedencentral | gpt-4o-rt-txt-1217 cchd Inp DZn             |          2.75  |
# | swedencentral | Grok-3 Outp glbl                            |         15     |
# | swedencentral | gpt 4o 1120 Batch Inp glbl                  |          1.25  |
# | swedencentral | R1 Outp glbl                                |          5.4   |
# | swedencentral | gpt 4o tcrb d txt out dz                    |         11     |
# | swedencentral | gpt-4o-mini-0718-Outp-regnl                 |          0.66  |
# | swedencentral | gpt 4o 1120 Batch Outp glbl                 |          5     |
# | swedencentral | gpt 5 pro inp dzone                         |         16.5   |
# | swedencentral | Llama 4 Maverick 17B Inp regnl              |          0.303 |
# | swedencentral | o1 1216 cached Inp glbl                     |          7.5   |
# | swedencentral | gpt4omini-rt-aud1217 Inp glbl               |         10     |
# | swedencentral | OCR regnl                                   |       1210     |
# | swedencentral | gpt 4.1 mini Batch Outp DZone               |          0.88  |
# | swedencentral | gpt-4o-aud-0603-txt Outp regnl              |         12.1   |
# | swedencentral | Phi-3.5-Mini-128K-Instruct-Input-Finetuned  |          0.13  |
# | swedencentral | Phi-3-Medium-128K-Instruct-Output-Finetuned |          0.68  |
# | swedencentral | gpt rt img 0828 cchd Inp glbl               |          0.5   |
# | swedencentral | Codestral Inp regnl                         |          0.363 |
# | swedencentral | Phi-4-Output-FT                             |          0.5   |
# | swedencentral | gpt-4o-mini-0718-FT-Trng-glbl               |          3     |
# | swedencentral | gpt 4o 0806 Outp Data Zone                  |         11     |
# | swedencentral | gpt 4.1 mini cached Inp glbl                |          0.1   |
# | swedencentral | gpt-35-turbo16K-FT-Inp-regnl                |          0.605 |
# | swedencentral | gpt-4-8K-FT-Inp-regnl                       |         30     |
# | swedencentral | o1 1216 Inp regnl                           |         18.15  |
# | swedencentral | computer-use-inpt-rgnl                      |          3.63  |
# | swedencentral | o1 model ft grader cched input              |          8.25  |
# | swedencentral | o1 1216 Outp glbl                           |         60     |
# | swedencentral | text-embedding-3-small-regional             |          0.025 |
# | swedencentral | gpt 4o 1120 Inp regnl                       |          3.025 |
# | swedencentral | gpt-4.1-mini-ft input global                |          0.4   |
# | swedencentral | babbage-002-FT-Trng-regnl tkn               |          0.4   |
# | swedencentral | Phi-4-reasoning-plus-input                  |          0.125 |
# | swedencentral | gpt-4o-rt-aud-1217 cchd Inp glbl            |          2.5   |
# | swedencentral | Phi-4-Mini MM-Output                        |          0.32  |
# | swedencentral | gpt rt aud 0828 Outp glbl                   |         64     |
# | swedencentral | o3 0416 cached Inp glbl                     |          0.5   |
# | swedencentral | gpt4omini-rt-aud1217 Outp DZone             |         22     |
# | swedencentral | gpt 4o 0513 Output regional                 |         18.15  |
# | swedencentral | gpt 5 pro out glbl                          |        120     |
# | swedencentral | Kontext Pro glbl                            |      40000     |
# | swedencentral | Phi-3-Small-8K-Instruct-Output              |          0.6   |
# | swedencentral | gpt 4.1 Outp Data Zone                      |          8.8   |
# | swedencentral | Llama 4 Maverick 17B Outp regnl             |          1.21  |
# | swedencentral | Phi-3-Medium-128K-Instruct-Output           |          0.68  |
# | swedencentral | gpt rt aud mini Inp glbl                    |         10     |
# | swedencentral | o3 0416 cached Inp Data Zone                |          0.55  |
# | swedencentral | Grok-3 Inp regnl                            |          3.63  |
# | swedencentral | o4-mini 0416 Batch Outp Data Zone           |          2.42  |
# | swedencentral | gpt 4o 0806 Inp Data Zone                   |          2.75  |
# | swedencentral | gpt 5 pro batch inp dzone                   |          8.25  |
# | swedencentral | gpt-4o-aud-0603 Outp DZone                  |         88     |
# | swedencentral | gpt4omini-rt-aud1217 Inp DZone              |         11     |
# | swedencentral | Phi-3-Mini-128K-Instruct-Output-Finetuned   |          0.52  |
# | swedencentral | Phi-3.5-V-128K-Instruct-Input               |          0.13  |
# | swedencentral | o3 0416 Batch Inp glbl                      |          1     |
# | swedencentral | gpt rt aud 0828 cchd Inp glbl               |          0.4   |
# | swedencentral | gpt aud mini Inp DZone                      |         11     |
# | swedencentral | gpt-4o-transcribe-aud-inp-glbl              |          6     |
# | swedencentral | gpt4omini-rt-txt1217 cchd Inp glbl          |          0.3   |
# | swedencentral | gpt-4.1-mini FT Training regional           |          6.05  |
# | swedencentral | o1 Batch Outp glbl                          |         30     |
# | swedencentral | gpt-image-1-inp-img-rgnl                    |         12.1   |
# | swedencentral | gpt aud 0828 Inp DZone                      |         44     |
# | swedencentral | gpt-4-turbo-Vision-128K Output-regional     |         36.3   |
# | swedencentral | gpt-4o-0806-Inp-glbl                        |          2.5   |
# | swedencentral | gpt-4o-aud-1217 Inp DZone                   |         44     |
# | swedencentral | gpt-4o-mini-transcribe-txt-inp-rgnl         |          1.513 |
# | swedencentral | gpt 4.1 mini Inp regnl                      |          0.484 |
# | swedencentral | gpt 41 mn pp inp glb                        |          0.7   |
# | swedencentral | gpt 41 pp cd inp glb                        |          0.875 |
# | swedencentral | gpt 4o tcrb d txt inp glbl                  |          2.5   |
# | swedencentral | gpt 4.1 nano Outp Data Zone                 |          0.44  |
# | swedencentral | gpt-4.1-mini-ft mdl grdr inpt               |          0.44  |
# | swedencentral | gpt-35-trb16K-Batch-Outp-glbl               |          1     |
# | swedencentral | gpt 4.5 0227 Inp glbl                       |         75     |
# | swedencentral | Command A Inp DZ                            |          2.75  |
# | swedencentral | gpt 4.1 nano Inp regnl                      |          0.121 |
# | swedencentral | Llama 4 Maverick 17B Inp Dzone              |          0.275 |
# | swedencentral | o3 0416 cached Inp regnl                    |          0.605 |
# | swedencentral | gpt 4.1 nano Batch Inp DZone                |          0.055 |
# | swedencentral | gpt4o realtime cached audio inp glbl        |         20     |
# | swedencentral | gpt-35-turbo-16K-1106 Input-regional        |          1.21  |
# | swedencentral | gpt-4o-rt-txt-0603 Inp DZone                |          5.5   |
# | swedencentral | Grok-3 Inp glbl                             |          3     |
# | swedencentral | o3-pro Batch Outp glbl                      |         40     |
# | swedencentral | gpt img 1 mini inp txt dzone                |          2.2   |
# | swedencentral | Grok 10 Inp DZone                           |          0.22  |
# | swedencentral | gpt 4o 0513 Output Data Zone                |         16.5   |
# | swedencentral | gpt 4.1 Batch Outp glbl                     |          4     |
# | swedencentral | o1 mini cached input Data Zone              |          0.605 |
# | swedencentral | Llama 3.3 70B Inp Dzone                     |          0.781 |
# | swedencentral | gpt-4.1-nano-ft cached input global         |          0.025 |
# | swedencentral | computer-use-outp-rgnl                      |         14.52  |
# | swedencentral | OSS-20b FT                                  |          3.6   |
# | swedencentral | gpt-4.1-nano FT Training global             |          1.5   |
# | swedencentral | o4-mini-ft input global                     |          1.1   |
# | swedencentral | gpt 4o mini 0718 cached Inp glbl            |          0.075 |
# | swedencentral | gpt-image-1-inp-txt-rgnl                    |          6.05  |
# | swedencentral | gpt-4.1-nano-ft mdl grdr opt                |          0.44  |
# | swedencentral | gpt-4o-aud-0603-txt Outp glbl               |         10     |
# | swedencentral | gpt-4o-0806-FT-inp-regnl                    |          2.75  |
# | swedencentral | gpt4omini-rt-aud1217 cchd Inp DZn           |          0.33  |
# | swedencentral | o1-pro Outp regnl                           |        726     |
# | swedencentral | gpt 5 pro inp glbl                          |         15     |
# | swedencentral | o3 0416 Inp Data Zone                       |          2.2   |
# | swedencentral | o1-pro Batch Outp Data Zone                 |        330     |
# | swedencentral | embedding-ada-datazone                      |          0.11  |
# | swedencentral | gpt 4o 1120 cached Inp glbl                 |          1.25  |
# | swedencentral | Phi-4-mini-reasoning-Output                 |          0.3   |
# | swedencentral | gpt-4.1-nano FT Training regional           |          1.815 |
# | swedencentral | o4 mini dev RFT cchd inpt glbl              |          0.275 |
# | swedencentral | gpt 4o 1120 Batch Outp DZ                   |          5.5   |
# | swedencentral | gpt 4.1 nano cached Inp DZone               |          0.028 |
# | swedencentral | o3-mini-ft model grader output              |          4.84  |
# | swedencentral | gpt-4.1-mini-ft cached input global         |          0.1   |
# | swedencentral | computer-use-outp-glbl                      |         12     |
# | swedencentral | gpt-4o-aud-1217 Outp DZone                  |         88     |
# | swedencentral | gpt 4o 0806 cached Inp glbl                 |          1.25  |
# | swedencentral | V3 Inp glbl                                 |          1.14  |
# | swedencentral | Llama3.3 70b-IN-FT                          |          0.71  |
# | swedencentral | Phi-3.5-MoE-Instruct-FT                     |          3     |
# | swedencentral | Phi-4-Mini MM-FT                            |          3     |
# | swedencentral | o1 1216 cached Inp regnl                    |          9.075 |
# | swedencentral | gpt-4o-mini-transcribe-txt-out-dz           |          5.5   |
# | swedencentral | V3 Outp DZone                               |          5     |
# | swedencentral | o3 0416 Batch Outp Data Zone                |          4.4   |
# | swedencentral | V3.2 Inp DZ                                 |          0.64  |
# | swedencentral | o1 mini input Data Zone                     |          1.21  |
# | swedencentral | gpt rt txt mini Inp glbl                    |          0.6   |
# | swedencentral | Phi-3-Medium-4K-Instruct-Input-Finetuned    |          0.17  |
# | swedencentral | gpt 41 prty inp glbl                        |          3.5   |
# | swedencentral | o1 1216 cached Inp Data Zone                |          8.25  |
# | swedencentral | Llama 4 Maverick 17B Outp glbl              |          1     |
# | swedencentral | Phi-4-Output                                |          0.5   |
# | swedencentral | gpt rt txt 0828 cchd Inp glbl               |          0.4   |
# | swedencentral | gpt rt txt 0828 Outp glbl                   |         16     |
# | swedencentral | gpt4omini-aud1217-txt Outp regnl            |          0.726 |
# | swedencentral | Phi-4-FT                                    |          3     |
# | swedencentral | Phi-3.5-V-128K-Instruct-Input-Finetuned     |          0.13  |
# | swedencentral | gpt-4o-transcribe-aud-inp-rgnl              |          7.26  |
# | swedencentral | gpt4o realtimePrvw audio inp glbl           |        100     |
# | swedencentral | gpt-4o-mini-0718-FT-outp-regnl              |          0.66  |
# | swedencentral | gpt rt img mini cchd Inp glbl               |          0.08  |
# | swedencentral | gpt 41 pp cd inp dz                         |          0.963 |
# | swedencentral | gpt-4o-rt-aud-1217 cchd Inp DZn             |          2.75  |
# | swedencentral | gpt-4o-0806-Outp-regnl                      |         11     |
# | swedencentral | gpt 4.1 nano Inp glbl                       |          0.1   |
# | swedencentral | babbage-002-FT-Outp-regnl                   |          0.4   |
# | swedencentral | Phi-3-Small-8K-Instruct-Input-Finetuned     |          0.15  |
# | swedencentral | gpt-5-codex-inp-dzone                       |          1.375 |
# | swedencentral | gpt 41 prty out glbl                        |         14     |
# | swedencentral | o1-pro Batch Inp Data Zone                  |         82.5   |
# | swedencentral | MAI-DS-R1 Inp glbl                          |          1.35  |
# | swedencentral | gpt-4.1-ft output regional                  |          9.68  |
# | swedencentral | o1-pro Batch Outp glbl                      |        300     |
# | swedencentral | o1 Batch Inp Data Zone                      |          8.25  |
# | swedencentral | gpt-4-turbo128K Outp-glbl                   |         30     |
# | swedencentral | gpt 4.1 mini Batch Inp DZone                |          0.22  |
# | swedencentral | o1 preview cached input Data Zone           |          8.25  |
# | swedencentral | Grok-4 Outp DZone                           |         16.5   |
# | swedencentral | gpt img 1 mini inp txt glbl                 |          2     |
# | swedencentral | gpt-4o-rt-aud-0603 Inp regnl                |         48.4   |
# | swedencentral | gpt-4o-aud-1217 Inp regnl                   |         48.4   |
# | swedencentral | Phi-4-Mini MM-Output-FT                     |          0.32  |
# | swedencentral | gpt-4o-aud-0603-txt Outp DZone              |         11     |
# | swedencentral | gpt rt txt 0828 cchd Inp DZn                |          0.44  |
# | swedencentral | gpt 4o 0806 Batch Inp Data Zone             |          1.375 |
# | swedencentral | gpt-4o-mini-tts-aud-out-dz                  |         13.2   |
# | swedencentral | gpt 41 mn cd pp inp glb                     |          0.175 |
# | swedencentral | gpt-35-turbo-4k-Output-regional             |          2     |
# | swedencentral | file-search-tool-calls-glbl                 |       2500     |
# | swedencentral | MAI-DS-R1 Outp glbl                         |          5.4   |
# | swedencentral | o1 1216 Batch Inp glbl                      |          7.5   |
# | swedencentral | V3.2 SP Outp DZ                             |          1.85  |
# | swedencentral | Phi-4-reasoning-plus-output                 |          0.5   |
# | swedencentral | gpt-35-turbo16K-FT-Inp-glbl                 |          0.5   |
# | swedencentral | gpt4o realtime cached text inp glbl         |          2.5   |
# | swedencentral | V3.2 Outp glbl                              |          1.68  |
# | swedencentral | gpt4o realtimePrvw audio inp regn           |        121     |
# | swedencentral | gpt-4o-transcribe-txt-out-dz                |         11     |
# | swedencentral | gpt 41 mn pp out dz                         |          3.08  |
# | swedencentral | gpt aud mini txt Outp DZone                 |          2.64  |
# | swedencentral | gpt 4.1 mini Inp Data Zone                  |          0.44  |
# | swedencentral | gpt-4-32K-Output-regional                   |        120     |
# | swedencentral | gpt 4.1 nano Batch Outp DZone               |          0.22  |
# | swedencentral | gpt-4o-mini-0718-Batch-Outp-glbl            |          0.3   |
# | swedencentral | gpt 4.1 mini Outp Data Zone                 |          1.76  |
# | swedencentral | o4 mini dev RFT inpt glbl                   |          1.1   |
# | swedencentral | Grok 10 Inp glbl                            |          0.2   |
# | swedencentral | gpt rt img 0828 Inp DZn                     |          5.5   |
# | swedencentral | Grok 6 Inp DZone                            |          0.22  |
# | swedencentral | gpt4o realtimePrvwAudInp DataZone           |        110     |
# | swedencentral | gpt-35-turbo16K-FT-Trng-regnl tkn           |          9.68  |
# | swedencentral | gpt4omini-rt-aud1217 Inp regnl              |         12.1   |
# | swedencentral | Phi-3-Mini-128K-Instruct-Finetuned          |          3     |
# | swedencentral | o1 preview output glbl                      |         60     |
# | swedencentral | Phi-3-Small-8K-Instruct-Output-Finetuned    |          0.6   |
# | swedencentral | gpt 4.1 Inp glbl                            |          2     |
# | swedencentral | gpt-4.1-nano-ft input global                |          0.1   |
# | swedencentral | o3-pro Outp Data Zone                       |          2.5   |
# | swedencentral | gpt-4o-0806-FT-outp-glbl                    |         10     |
# | swedencentral | Doc AI regnl 2505                           |       3630     |
# | swedencentral | gpt-4o-0806-FT-inp-glbl                     |          2.5   |
# | swedencentral | gpt-4o-mini-0718-Batch-Inp-glbl             |          0.075 |
# | swedencentral | gpt-4o-mini-tts-txt-inp-dz                  |          0.66  |
# | swedencentral | gpt4o realtime cached audio inp regn        |         24.2   |
# | swedencentral | gpt-4o-aud-0603 Outp glbl                   |         80     |
# | swedencentral | gpt-4o-rt-txt-1217 Inp regnl                |          6.05  |
# | swedencentral | gpt-4o-transcribe-aud-inp-dz                |          6.6   |
# | swedencentral | gpt4omini-aud1217 Outp glbl                 |         20     |
# | swedencentral | Grok-4 Inp DZone                            |          3.3   |
# | swedencentral | gpt-4o-rt-aud-1217 Outp glbl                |         80     |
# | swedencentral | V3-0324 Outp DZone                          |          5     |
# | swedencentral | o4 mini dev RFT opt glbl                    |          4.4   |
# | swedencentral | Codestral Outp DZone                        |          0.99  |
# | swedencentral | gpt4omini-aud1217 Inp regnl                 |         12.1   |
# | swedencentral | gpt-image-1-inp-txt-dzone                   |          5.5   |
# | swedencentral | gpt-4.1-ft mdl grdr inpt                    |          2.2   |
# | swedencentral | gpt4omini-aud1217-txt Outp glbl             |          0.6   |
# | swedencentral | gpt-oss-120B Outp glbl                      |          0.6   |
# | swedencentral | codex mini inp glbl                         |          1.5   |
# | swedencentral | gpt-4-32K-Input-regional                    |         60     |
# | swedencentral | gpt rt txt mini cchd Inp DZn                |          0.066 |
# | swedencentral | gpt-4o-0806-cached-FT-inp-glbl              |          1.25  |
# | swedencentral | Phi-3-Medium-4K-Instruct-Input              |          0.17  |
# | swedencentral | R3 Inp DZone                                |          1.23  |
# | swedencentral | codex mini inp dzone                        |          1.65  |
# | swedencentral | computer-use-inpt-glbl                      |          3     |
# | swedencentral | gpt-35-turbo-16K-0125 Output-regional       |          1.815 |
# | swedencentral | gpt4o realtimePrvw audio outp regn          |        242     |
# | swedencentral | gpt 4o mini 0718 Batch Inp Data Zone        |          0.083 |
# | swedencentral | gpt-4o-aud-1217-txt Outp regnl              |         12.1   |
# | swedencentral | o1 model ft grader input                    |         16.5   |
# | swedencentral | gpt-4o-0806-Inp-regnl                       |          2.75  |
# | swedencentral | Doc AI DZone 2505                           |       3300     |
# | swedencentral | gpt-5-codex-inp-glbl                        |          1.25  |
# | swedencentral | o3-ft mdl grdr inpt                         |          2.2   |
# | swedencentral | Phi-3-Mini-128K-Instruct-Input              |          0.13  |
# | swedencentral | gpt 4o 0513 Input global                    |          5     |
# | swedencentral | Llama 4 Maverick 17B Outp Dzone             |          1.1   |
# | swedencentral | gpt-4.1-nano-ft mdl grdr cchd inpt          |          0.028 |
# | swedencentral | o1 mini cached input glbl                   |          0.55  |
# | swedencentral | codex mini inp cchd rgnl                    |          0.454 |
# | swedencentral | o1 mini Batch Inp glbl                      |          0.55  |
# | swedencentral | OCR DZone                                   |       1100     |
# | swedencentral | Phi-4-Mini MM-Input                         |          0.08  |
# | swedencentral | file-search-tool-calls-datazone             |       2750     |
# | swedencentral | o3-pro Outp glbl                            |         80     |
# | swedencentral | gpt-35-turbo-4k-Input-regional              |          1.5   |
# | swedencentral | o3 0416 Inp glbl                            |          2     |
# | swedencentral | o1 preview cached input glbl                |          7.5   |
# | swedencentral | gpt 4.1 Inp Data Zone                       |          2.2   |
# | swedencentral | gpt-35-trb16K-Batch-Inp-glbl                |          0.5   |
# | swedencentral | o1 1216 Outp Data Zone                      |         66     |
# | swedencentral | o4-mini-ft model grader input               |          1.21  |
# | swedencentral | GPT-OSS-20b-Out-FT                          |          0.3   |
# | swedencentral | Phi-4-Input                                 |          0.125 |
# | swedencentral | gpt-4.1-ft input regional                   |          2.42  |
# | swedencentral | gpt-4.1-mini-ft mdl grdr opt                |          1.76  |
# | swedencentral | Llama 3.3 70B Outp glbl                     |          0.71  |
# | swedencentral | gpt-4o-rt-txt-0603 Outp glbl                |         20     |
# | swedencentral | gpt-4.1 FT Training global                  |         25     |
# | swedencentral | Mistral model 1 FT                          |          1     |
# | swedencentral | gpt4o realtime prvw text outp regn          |         24.2   |
# | swedencentral | o1 preview input regnl                      |         16.5   |
# | swedencentral | gpt-4o-transcribe-txt-out-glbl              |         10     |
# | swedencentral | Phi-3-Mini-4K-Instruct-Output               |          0.52  |
# | swedencentral | Phi-4-Mini MM-Input-FT                      |          0.08  |
# | swedencentral | Qwen3 32B FT                                |          3.2   |
# | swedencentral | Phi-4-Mini MM-Audio-In                      |          4     |
# | swedencentral | o1 1216 Inp Data Zone                       |         16.5   |
# | swedencentral | gpt4omini-rt-txt1217 cchd Inp rgnl          |          0.363 |
# | swedencentral | Phi-3-Small-8K-Instruct-Input               |          0.15  |
# | swedencentral | gpt-image-1-output-img-rgnl                 |         48.4   |
# | swedencentral | o3-pro Outp regnl                           |         12.5   |
# | swedencentral | gpt-35-trb16K-Batch-125-Inp-glbl            |          0.25  |
# | swedencentral | Grok-3 Mini Inp Dzone                       |          0.275 |
# | swedencentral | o1 1216 Batch Inp Data Zone                 |          8.25  |
# | swedencentral | gpt rt aud mini cchd Inp DZn                |          0.33  |
# | swedencentral | gpt-4o-rt-aud-1217 Outp regnl               |         96.8   |
# | swedencentral | gpt-4-turbo-Vision-128K Input-regional      |         12.1   |
# | swedencentral | o3 0416 Outp glbl                           |          8     |
# | swedencentral | K2 Thinking Inp glbl                        |          0.6   |
# | swedencentral | gpt-4-turbo-128K Input-regional             |         12.1   |
# | swedencentral | Mistral model 1-Out-FT                      |          0.15  |
# | swedencentral | gpt-4.1-ft output global                    |          8     |
# | swedencentral | gpt img 1 mini inp cchd img dzone           |          0.275 |
# | swedencentral | gpt 4o mini 0718 Outp Data Zone             |          0.66  |
# | swedencentral | gpt-4o-mini-tts-txt-inp-glbl                |          0.6   |
# | swedencentral | gpt-oss-120B Outp DZone                     |          0.66  |
# | swedencentral | gpt 41 mn pp out glb                        |          2.8   |
# | swedencentral | gpt rt aud 0828 Inp glbl                    |         32     |
# | swedencentral | gpt-4o-rt-aud-1217 Inp glbl                 |         40     |
# | swedencentral | gpt 4o tcrb d aud inp dz                    |          6.6   |
# | swedencentral | gpt-4o-0806-Outp-glbl                       |         10     |
# | swedencentral | gpt 4.1 Outp glbl                           |          8     |
# | swedencentral | gpt 4o 0806 Batch Outp Data Zone            |          5.5   |
# | swedencentral | gpt-35-turbo4K-FT-Trng-regnl tkn            |          9.68  |
# | swedencentral | Phi-3-Medium-4K-Instruct-Output-Finetuned   |          0.68  |
# | swedencentral | Large 3 Inp glbl                            |          0.5   |
# | swedencentral | gpt aud mini txt Inp glbl                   |          0.6   |
# | swedencentral | gpt-4.1-dev-ft opt glbl                     |          8     |
# | swedencentral | gpt img 1 mini inp cchd img glbl            |          0.25  |
# | swedencentral | gpt-4o-0806-Batch-Inp-glbl                  |          1.25  |
# | swedencentral | gpt 4.1 Batch Inp Data Zone                 |          1.1   |
# | swedencentral | gpt rt img mini Inp glbl                    |          0.8   |
# | swedencentral | o4-mini 0416 cached Inp glbl                |          0.275 |
# | swedencentral | gpt-4o-rt-txt-0603 cchd Inp glbl            |          2.5   |
# | swedencentral | Codestral Inp glbl                          |          0.3   |
# | swedencentral | gpt 4.1 mini cached Inp DZone               |          0.11  |
# | swedencentral | Az-GPT-35-turboArmSkuName                   |          2     |
# | swedencentral | V3.2 SP Outp glbl                           |          1.68  |
# | swedencentral | gpt-4o-0806-Batch-Outp-glbl                 |          5     |
# | swedencentral | gpt-4o-rt-aud-0603 Inp glbl                 |         40     |
# | swedencentral | Phi-3-Medium-128K-Instruct-Finetuned        |          3     |
# | swedencentral | computer-use-outp-datazone                  |         13.2   |
# | swedencentral | gpt 4.1 mini Batch Inp glbl                 |          0.2   |
# | swedencentral | text-embedding-3-large-glbl                 |          0.13  |
# | swedencentral | Embed v3 Glbl                               |          0.47  |
# | swedencentral | V3.2 Inp glbl                               |          0.58  |
# | swedencentral | Large 3 Inp Dzone                           |          0.55  |
# | swedencentral | gpt-35-turbo-16K-1106 Output-regional       |          2.42  |
# | swedencentral | gpt 4.1 mini Inp glbl                       |          0.4   |
# | swedencentral | gpt-4o-aud-0603-txt Inp glbl                |          2.5   |
# | swedencentral | gpt 4.1 nano Inp Data Zone                  |          0.11  |
# | swedencentral | gpt-35-turbo-16k-Input-regional             |          3     |
# | swedencentral | gpt 4o 1120 Outp Data Zone                  |         11     |
# | swedencentral | gpt-4-8K-Output-regional                    |         60     |
# | swedencentral | Grok 10 Outp DZone                          |          0.55  |
# | swedencentral | OCR 1125 glbl                               |       2000     |
# | swedencentral | o4-mini 0416 cached Inp DataZone            |          0.303 |
# | swedencentral | gpt rt txt 0828 Outp DZone                  |         17.6   |
# | swedencentral | gpt-4.1-nano-ft output global               |          0.4   |
# | swedencentral | gpt-4.1-nano-dev-ft opt glbl                |          0.4   |
# | swedencentral | Phi-3-Medium-4K-Instruct-Finetuned          |          3     |
# | swedencentral | K2 Thinking Outp glbl                       |          2.5   |
# | swedencentral | gpt rt img mini Inp DZn                     |          0.88  |
# | swedencentral | gpt-4o-aud-0603 Outp regnl                  |         96.8   |
# | swedencentral | gpt-35-turbo4K-FT-Inp-regnl                 |          0.605 |
# | swedencentral | o4-mini-ft cached input global              |          0.275 |
# | swedencentral | gpt-4o-aud-0603 Inp regnl                   |         48.4   |
# | swedencentral | gpt 4.5 0227 cached Inp glbl                |         37.5   |
# | swedencentral | K2 Thinking Inp DZ                          |          0.66  |
# | swedencentral | gpt-4o-rt-txt-1217 Outp DZone               |         22     |
# | swedencentral | o3 mini 0131 cached input regnl             |          0.666 |
# | swedencentral | o4-mini-ft output regional                  |          5.324 |
# | swedencentral | text embedding 3 small DZ                   |          0.022 |
# | swedencentral | OCR glbl                                    |       1000     |
# | swedencentral | gpt-4o-rt-txt-0603 cchd Inp DZn             |          2.75  |
# | swedencentral | gpt-4o-ft model grader input                |          2.75  |
# | swedencentral | o1 mini input glbl                          |          1.1   |
# | swedencentral | Grok-4 Outp glbl                            |         15     |
# | swedencentral | gpt4omini-rt-txt1217 Outp glbl              |          2.4   |
# | swedencentral | Phi-3-Small-128K-Instruct-Output-Finetuned  |          0.6   |
# | swedencentral | gpt-4o-mini-0718-Inp-glbl                   |          0.15  |
# | swedencentral | gpt4o rtime cached txt inp datazone         |          2.75  |
# | swedencentral | gpt-4o-rt-txt-1217 Outp regnl               |         24.2   |
# | swedencentral | o3-ft mdl grdr opt                          |          8.8   |
# | swedencentral | Grok-3 Mini Outp glbl                       |          1.27  |
# | swedencentral | gpt-4o-transcribe-txt-inp-glbl              |          2.5   |
# | swedencentral | gpt rt aud mini Outp DZone                  |         22     |
# | swedencentral | o1 mini Batch Outp Data Zone                |          2.42  |
# | swedencentral | o4-mini-ft output global                    |          4.4   |
# | swedencentral | gpt-image-1-inp-txt-glbl                    |          5     |
# | swedencentral | Phi-3-Small-128K-Instruct-Finetuned         |          3     |
# | swedencentral | gpt 4o 0513 Batch Inp glbl                  |          2.5   |
# | swedencentral | o1 mini Batch Outp glbl                     |          2.2   |
# | swedencentral | gpt aud mini Outp DZone                     |         22     |
# | swedencentral | gpt-4.1-ft input global                     |          2     |
# | swedencentral | o4-mini 0416 Outp regnl                     |          5.324 |
# | swedencentral | o1-pro Outp glbl                            |        600     |
# | swedencentral | gpt4omini-aud1217 Inp glbl                  |         10     |
# | swedencentral | o1 1216 Batch Outp glbl                     |         30     |
# | swedencentral | Phi-4-Input-FT                              |          0.125 |
# | swedencentral | gpt-4o-rt-aud-0603 cchd Inp rgnl            |          3.025 |
# | swedencentral | gpt-4.1-mini-dev-ft opt glbl                |          1.6   |
# | swedencentral | gpt-4o-rt-txt-0603 cchd Inp rgnl            |          3.025 |
# | swedencentral | Code Fast 1 Inp glbl                        |          0.2   |
# | swedencentral | Llama 3.3 70B Outp Dzone                    |          0.781 |
# | swedencentral | Codestral Outp glbl                         |          0.9   |
# | swedencentral | Grok-3 Outp regnl                           |         18.15  |
# | swedencentral | o4-mini 0416 Batch Inp glbl                 |          0.55  |
# | swedencentral | gpt-4.1-ft cached input global              |          0.5   |
# | swedencentral | Phi-4-Mini-Output-FT                        |          0.3   |
# | swedencentral | Grok-3 Mini Outp regnl                      |          1.5   |
# | swedencentral | gpt-4o-mini-ft mdel grdr cched inpt         |          0.083 |
# | swedencentral | gpt-4o-rt-aud-1217 cchd Inp rgnl            |          3.025 |
# | swedencentral | Command A Outp DZ                           |         11     |
# | swedencentral | gpt-4o-rt-txt-1217 Inp DZone                |          5.5   |
# | swedencentral | R2 Inp DZone                                |          1.36  |
# | swedencentral | gpt rt aud mini Inp DZone                   |         11     |
# | swedencentral | gpt-4o-0806-FT-Trng-regnl tkn               |         27.5   |
# | swedencentral | text-embedding-3-large-grader               |          0.13  |
# | swedencentral | Grok-3 Outp DZone                           |         16.5   |
# | swedencentral | gpt4omini-aud1217 Inp DZone                 |         11     |
# | swedencentral | gpt-4o-transcribe-txt-out-rgnl              |         12.1   |
# | swedencentral | Az-GPT4-Turbo-128K Input                    |         10     |
# | swedencentral | gpt rt img 0828 Inp glbl                    |          5     |
# | swedencentral | gpt-4o-aud-0603-txt Inp regnl               |          3.025 |
# | swedencentral | Phi-4-reasoning-Input                       |          0.125 |
# | swedencentral | gpt 4.1 Batch Outp Data Zone                |          4.4   |
# | swedencentral | o1 mini cached input regnl                  |          0.666 |
# | swedencentral | gpt-4o-aud-1217-txt Inp regnl               |          3.025 |
# | swedencentral | gpt 4.1 cached Inp regnl                    |          0.605 |
# | swedencentral | gpt-35-turbo-Instruct-Input-regional        |          1.815 |
# | swedencentral | gpt aud mini txt Inp DZone                  |          0.66  |
# | swedencentral | gpt-4o-ft model grader output               |         11     |
# | swedencentral | Grok-4 Inp glbl                             |          3     |
# | swedencentral | gpt-image-1-output-img-glbl                 |         40     |
# | swedencentral | gpt-4o-rt-txt-0603 Inp glbl                 |          5     |
# | swedencentral | gpt rt aud 0828 cchd Inp DZn                |          0.44  |
# | swedencentral | gpt-4o-mini-0718-Inp-regnl                  |          0.165 |
# | swedencentral | Phi-3-Mini-4K-Instruct-Output-Finetuned     |          0.52  |
# | swedencentral | gpt aud 0828 Outp DZone                     |         88     |
# | swedencentral | Command A Inp Glbl                          |          2.5   |
# | swedencentral | gpt aud 0828 txt Inp glbl                   |          2.5   |
# | swedencentral | Llama 4 Maverick 17B Inp glbl               |          0.25  |
# | swedencentral | o3-pro Batch Inp Data Zone                  |         11     |
# | swedencentral | o3 mini 0131 input regnl                    |          1.331 |
# | swedencentral | o3 0416 Outp Data Zone                      |          8.8   |
# | swedencentral | o1 mini output Data Zone                    |          4.84  |
# | swedencentral | gpt4o realtime prvw text inp regn           |          6.05  |
# | swedencentral | Flux 1.1 Pro glbl                           |      40000     |
# | swedencentral | o4-mini-ft model grader cchd inp            |          0.303 |
# | swedencentral | codex mini inp rgnl                         |          1.815 |
# | swedencentral | gpt aud mini Inp glbl                       |         10     |
# | swedencentral | gpt aud 0828 txt Inp DZone                  |          2.75  |
# | swedencentral | Embed v4 Glbl                               |          0.12  |
# | swedencentral | gpt-35-turbo-Instruct-Output-regional       |          2.42  |
# | swedencentral | o3 mini 0131 cached input Data Zone         |          0.605 |
# | swedencentral | Qwen3 32B-IN-FT                             |          0.3   |
# | swedencentral | o4-mini-ft model grader output              |          4.84  |
# | swedencentral | gpt 4.1 Outp regnl                          |          9.68  |
# | swedencentral | Llama3.3-Out-FT                             |          0.71  |
# | swedencentral | codex mini inp cchd dzone                   |          0.413 |
# | swedencentral | davinci-002-FT-Outp-regnl                   |          2     |
# | swedencentral | gpt 4.1 mini Outp regnl                     |          1.936 |
# | swedencentral | gpt-4.1-nano-ft output regional             |          0.484 |
# | swedencentral | o4-mini 0416 cached Inp regnl               |          0.333 |
# | swedencentral | gpt4omini-aud1217 Outp DZone                |         22     |
# | swedencentral | gpt-4-8K-FT-Trng-regnl tkn                  |         80     |
# | swedencentral | 3.3 70b FT                                  |          4.5   |
# | swedencentral | gpt-4o-mini-transcribe-txt-out-rgnl         |          6.05  |
# | swedencentral | o3 mini 0131 Batch Inp Data Zone            |          0.605 |
# | swedencentral | gpt 5 pro batch out glbl                    |         60     |
# | swedencentral | gpt rt txt mini Outp DZone                  |          2.64  |
# | swedencentral | Codestral Outp regnl                        |          1.089 |
# | swedencentral | R2 Outp DZone                               |          5.43  |
# | swedencentral | gpt-image-1-inp-cached-img-rgnl             |          3.025 |
# | swedencentral | V3-0324 Inp glbl                            |          1.14  |
# | swedencentral | gpt rt img mini cchd Inp DZn                |          0.088 |
# | swedencentral | gpt-oss-120B Inp glbl                       |          0.15  |
# | swedencentral | Codestral Inp DZone                         |          0.33  |
# | swedencentral | Phi-4-Mini-Input                            |          0.075 |
# | swedencentral | gpt-image-1-inp-cached-txt-glbl             |          1.25  |
# | swedencentral | gpt rt aud mini Outp glbl                   |         20     |
# | swedencentral | gpt 4o tcrb d aud inp glbl                  |          6     |
# | swedencentral | gpt rt txt mini Inp DZone                   |          0.66  |
# | swedencentral | gpt-image-1-inp-img-glbl                    |         10     |
# | swedencentral | Phi-3-Small-128K-Instruct-Output            |          0.6   |
# | swedencentral | codex mini out glbl                         |          6     |
# | swedencentral | Phi-4-Mini-FT                               |          3     |
# | swedencentral | gpt-35-turbo16K-FT-Outp-glbl                |          1.5   |
# | swedencentral | o3-mini-ft model grader cchd inpt           |          0.605 |
# | swedencentral | o4-mini 0416 Outp Data Zone                 |          4.84  |
# | swedencentral | gpt-4-8K-Input-regional                     |         30     |
# | swedencentral | o3 mini 0131 Batch Inp glbl                 |          0.55  |
# | swedencentral | K2 Thinking Outp DZ                         |          2.75  |
# | swedencentral | gpt img 1 mini inp img dzone                |          2.75  |
# | swedencentral | o1 1216 Outp regnl                          |         72.6   |
# | swedencentral | V3 Inp DZone                                |          1.25  |
# | swedencentral | Rerank v4 Pro Glbl                          |       2500     |
# | swedencentral | gpt4o realtime prvw text outp glbl          |         20     |
# | swedencentral | Model 2 Outp DZ                             |          3.3   |
# | swedencentral | gpt-4.1 FT Training regional                |         30.25  |
# | swedencentral | o4-mini 0416 Inp glbl                       |          1.1   |
# | swedencentral | embedding-ada-glbl                          |          0.1   |
# | swedencentral | gpt 4o tcrb d txt inp dz                    |          2.75  |
# | swedencentral | gpt-35-turbo-16K-0125 Input-regional        |          0.605 |
# | swedencentral | gpt 4o 1120 Outp regnl                      |         12.1   |
# | swedencentral | Phi-3.5-Mini-128K-Instruct-Input            |          0.13  |
# | swedencentral | o1 mini output glbl                         |          4.4   |
# | swedencentral | gpt-4o-0806-FT-Trng-glbl tkn                |         25     |
# | swedencentral | Phi-3-Mini-128K-Instruct-Output             |          0.52  |
# | swedencentral | Phi-4-Mini-Input-FT                         |          0.075 |
# | swedencentral | gpt aud 0828 Outp glbl                      |         80     |
# | swedencentral | gpt-4.1-mini-dev-ft inpt glbl               |          0.4   |
# | swedencentral | gpt4o realtimePrvwAudOutp DataZone          |        220     |
# | swedencentral | gpt4o rtime cached txt inp rgnl             |          3.025 |
# | swedencentral | gpt4omini-aud1217 Outp regnl                |         24.2   |
# | swedencentral | Grok 6 Inp glbl                             |          0.2   |
# | swedencentral | gpt-4o-mini-0718-FT-inp-regnl               |          0.165 |
# | swedencentral | gpt rt aud mini cchd Inp glbl               |          0.3   |
# | swedencentral | gpt-5-codex-out-dzone                       |         11     |
# | swedencentral | o3 mini 0131 output glbl                    |          4.4   |
# | swedencentral | gpt 4o 0513 Batch Outp glbl                 |          7.5   |
# | swedencentral | text-embedding-3-large-regional             |          0.158 |
# | swedencentral | gpt img 1 mini inp cchd txt glbl            |          0.2   |
# | swedencentral | gpt-4o-aud-1217-txt Inp glbl                |          2.5   |
# | swedencentral | Llama 3.3 70B Inp glbl                      |          0.71  |
# | swedencentral | gpt 4.1 mini Batch Outp glbl                |          0.8   |
# | swedencentral | Phi-3-Medium-128K-Instruct-Input-Finetuned  |          0.17  |
# | swedencentral | o4-mini 0416 Inp Data Zone                  |          1.21  |
# | swedencentral | V3 Outp glbl                                |          4.56  |
# | swedencentral | V3-0324 Outp glbl                           |          4.56  |
# | swedencentral | o3 mini 0131 cached input glbl              |          0.55  |
# | swedencentral | gpt-4o-mini-0718-FT-inp-glbl                |          0.15  |
# | swedencentral | gpt-4.1-mini-ft output regional             |          1.936 |
# | swedencentral | gpt 4o 0806 cached Inp Data Zone            |          1.375 |
# | swedencentral | Llama 3.3 70B Outp regnl                    |          0.859 |
# | swedencentral | davinci-002-FT-Trng-regnl tkn               |          6     |
# | swedencentral | gpt-35-trb16K-Batch-125-Outp-glbl           |          0.75  |
# | swedencentral | gpt 4.1 cached Inp Data Zone                |          0.55  |
# | swedencentral | gpt 4o mini 0718 Inp Data Zone              |          0.165 |
# | swedencentral | gpt 4.5 0227 Outp glbl                      |        150     |
# | swedencentral | gpt 4.1 nano Batch Outp glbl                |          0.2   |
# | swedencentral | gpt-4o-aud-0603 Inp DZone                   |         44     |
# | swedencentral | Phi-3-Medium-4K-Instruct-Output             |          0.68  |
# | swedencentral | gpt4omini-rt-txt1217 Outp regnl             |          2.904 |
# | swedencentral | gpt-4o-rt-txt-1217 Outp glbl                |         20     |
# | swedencentral | Phi-3.5-Mini-128K-Instruct-Output-Finetuned |          0.52  |
# | swedencentral | gpt 4o tcrb d txt out glbl                  |         10     |
# | swedencentral | Llama 3.3 70B Inp regnl                     |          0.859 |
# | swedencentral | o1-pro Outp Data Zone                       |        660     |
# | swedencentral | o3-ft mdl grdr cchd inpt                    |          0.55  |
# | swedencentral | gpt-4o-rt-txt-1217 cchd Inp glbl            |          2.5   |
# | swedencentral | gpt 5 pro batch inp glbl                    |          7.5   |
# | swedencentral | gpt-35-turbo16K-FT-Outp-regnl               |          1.815 |
# | swedencentral | gpt-4.1-mini-ft mdl grdr cchd inpt          |          0.11  |
# | swedencentral | Phi-3-Mini-4K-Instruct-Input-Finetuned      |          0.13  |
# | swedencentral | Doc AI glbl 2505                            |       3000     |
# | swedencentral | gpt4o realtimePrvw audio outp glbl          |        200     |
# | swedencentral | gpt 4.1 nano Outp glbl                      |          0.4   |
# | swedencentral | o3-pro Batch Inp glbl                       |         10     |
# | swedencentral | gpt-4o-mini-transcribe-aud-inp-dz           |          3.3   |
# | swedencentral | o1-pro Inp Data Zone                        |        165     |
# | swedencentral | gpt-4.1-ft cached input regional            |          0.605 |
# | swedencentral | o1 model ft grader output                   |         66     |
# | swedencentral | GPT-OSS-20b-IN-FT                           |          0.07  |
# | swedencentral | o1-pro Batch Inp glbl                       |         75     |
# | swedencentral | gpt rt txt mini cchd Inp glbl               |          0.06  |
# | swedencentral | codex mini out rgnl                         |          7.26  |
# | swedencentral | gpt aud mini Outp glbl                      |         20     |
# | swedencentral | text embedding 3 large DZ                   |          0.143 |
# | swedencentral | gpt 4o 1120 cached Inp regnl                |          1.513 |
# | swedencentral | Phi-3.5-V-128K-Instruct-Output-Finetuned    |          0.52  |
# | swedencentral | gpt-image-1-inp-cached-txt-dzone            |          1.375 |
# | swedencentral | Phi-3-Small-128K-Instruct-Input-Finetuned   |          0.15  |
# | swedencentral | gpt-4o-0806-cached-FT-inp-regnl             |          1.513 |
# | swedencentral | gpt-35-turbo4K-FT-Outp-regnl                |          1.815 |
# | swedencentral | gpt4omini-rt-txt1217 cchd Inp DZn           |          0.33  |
# | swedencentral | o1 preview input glbl                       |         15     |
# | swedencentral | computer-use-inpt-datazone                  |          3.3   |
# | swedencentral | gpt aud 0828 Inp glbl                       |         40     |
# | swedencentral | gpt-4-8K-FT-Outp-regnl                      |         60     |
# | swedencentral | o3 0416 Batch Inp Data Zone                 |          1.1   |
# | swedencentral | gpt-4.1-ft mdl grdr cchd inpt               |          0.55  |
# | swedencentral | Code Fast 1 Outp glbl                       |          1.5   |
# | swedencentral | o1 1216 Batch Outp Data Zone                |         33     |
# | swedencentral | gpt 4.1 mini Outp glbl                      |          1.6   |
# | swedencentral | gpt img 1 mini out img dzone                |          8.8   |
# | swedencentral | Phi-4-mini-reasoning-Input                  |          0.075 |
# | swedencentral | Phi-3.5-V-128K-Instruct-Output              |          0.52  |
# | swedencentral | gpt-4.1-nano-dev-ft cchd inpt glbl          |          0.025 |
# | swedencentral | gpt 4o mini 0718 cached Inp regnl           |          0.091 |
# | swedencentral | gpt4omini-aud1217-txt Inp regnl             |          0.182 |
# | swedencentral | Phi-3.5-MoE-Instruct-Input-FT               |          0.16  |
# | swedencentral | gpt4omini-aud1217-txt Inp glbl              |          0.15  |
# | swedencentral | gpt-4o-rt-txt-1217 Inp glbl                 |          5     |
# | swedencentral | gpt rt aud 0828 Inp DZone                   |         35.2   |
# | swedencentral | gpt 41 mn pp cd inp dz                      |          0.193 |
# | swedencentral | Phi-3-Small-8K-Instruct-Finetuned           |          3     |
# | swedencentral | o1 preview output regnl                     |         66     |
# | swedencentral | Rerank v4 Pro DZ                            |       2750     |
# | swedencentral | gpt rt txt 0828 Inp glbl                    |          4     |
# | swedencentral | MAI-DS-R1 Outp Dzone                        |          5.94  |
# | swedencentral | gpt-4o-aud-1217 Outp regnl                  |         96.8   |
# | swedencentral | gpt 4o 1120 Outp glbl                       |         10     |
# | swedencentral | gpt4o rtime cached audio inp dzone          |         22     |
# | swedencentral | Phi-3-Mini-4K-Instruct-Finetuned            |          3     |
# | swedencentral | gpt rt img 0828 cchd Inp DZn                |          0.55  |
# | swedencentral | gpt-4o-aud-1217-txt Outp glbl               |         10     |
# | swedencentral | Grok-3 Inp DZone                            |          3.3   |
# | swedencentral | gpt-4.1-nano-dev-ft inpt glbl               |          0.1   |
# | swedencentral | gpt-4o-rt-aud-0603 Outp regnl               |         96.8   |
# | swedencentral | gpt-5-codex-ccchd-inp-dzone                 |          0.138 |
# | swedencentral | Grok 6 Outp DZone                           |          0.55  |
# | swedencentral | gpt-4.1-nano-ft mdl grdr inpt               |          0.11  |
# | swedencentral | gpt 41 prty inp dzone                       |          3.85  |
# | swedencentral | gpt4o realtime prvw text inp glbl           |          5     |
# | swedencentral | o3 mini 0131 input Data Zone                |          1.21  |
# | swedencentral | gpt-4o-rt-aud-0603 Inp DZone                |         44     |
# | swedencentral | Phi-3.5-Mini-128K-Instruct-Output           |          0.52  |
# | swedencentral | o4-mini-ft input regional                   |          1.331 |
# | swedencentral | gpt 4o mini0718 BatchOutp DataZone          |          0.33  |
# | swedencentral | gpt-4o-rt-txt-0603 Outp DZone               |         22     |
# | swedencentral | text-embedding-3-small-glbl                 |          0.02  |
# | swedencentral | gpt-4o-rt-aud-0603 cchd Inp glbl            |          2.5   |
# | swedencentral | gpt4omini-rt-aud1217 Outp glbl              |         20     |
# | swedencentral | o1 mini output regnl                        |          5.324 |
# | swedencentral | Code Fast 1 Outp DZone                      |          1.65  |
# | swedencentral | o3 mini 0131 input glbl                     |          1.1   |
# | swedencentral | o4-mini 0416 Inp regnl                      |          1.331 |
# | swedencentral | gpt 4.1 Batch Inp glbl                      |          1     |
# | swedencentral | gpt-4o-rt-aud-1217 Outp DZone               |         88     |
# | swedencentral | embedding-ada-regional                      |          0.121 |
# | swedencentral | gpt 4.1 nano Outp regnl                     |          0.484 |
# | swedencentral | gpt 41 prty out dzone                       |         15.4   |
# | swedencentral | Command A Outp Glbl                         |         10     |
# | swedencentral | Phi-3.5-MoE-Instruct-Input                  |          0.16  |
# | swedencentral | gpt-4o-mini-tts-txt-inp-rgnl                |          0.726 |
# | swedencentral | gpt 4o 1120 Batch Inp DZ                    |          1.375 |
# | swedencentral | gpt 5 pro batch out dzone                   |         66     |
# | swedencentral | gpt 4o 0513 Batch Outp Data Zone            |          8.25  |
# | swedencentral | gpt-4o-mini-tts-aud-out-rgnl                |         14.52  |
# | swedencentral | gpt-4.1-ft mdl grdr opt                     |          8.8   |
# | swedencentral | gpt-oss-120B Inp DZone                      |          0.165 |
# | swedencentral | gpt-4o-rt-txt-0603 Outp regnl               |         24.2   |
# | swedencentral | Rerank v4 Fast Glbl                         |       2000     |
# | swedencentral | gpt-4o-mini-ft model grader input           |          0.165 |
# | swedencentral | gpt aud 0828 txt Outp DZone                 |         11     |
# | swedencentral | o1-pro Inp glbl                             |        150     |
# | swedencentral | o3 0416 Outp regnl                          |          9.68  |
# | swedencentral | gpt-4-8K-Batch-Outp-glbl                    |         30     |
# | swedencentral | gpt-image-1-inp-cached-img-dzone            |          2.75  |
# | swedencentral | o1 1216 Inp glbl                            |         15     |
# | swedencentral | gpt-4o-rt-txt-0603 Inp regnl                |          6.05  |
# | swedencentral | gpt-image-1-inp-cached-img-glbl             |          2.5   |
# | swedencentral | Phi-3-Mini-128K-Instruct-Input-Finetuned    |          0.13  |
# | swedencentral | gpt-4.1-mini FT Training global             |          5     |
# | swedencentral | o4-mini-ft cached input regional            |          0.333 |
# | swedencentral | Code Fast 1 Inp DZone                       |          0.22  |
# | swedencentral | o3-pro Inp glbl                             |         20     |
# | swedencentral | gpt-4o-mini-0718-FT-Outp-glbl               |          0.6   |
# | swedencentral | gpt-4o-aud-0603 Inp glbl                    |         40     |
# | swedencentral | gpt-5-codex-out-glbl                        |         10     |
# | swedencentral | R1 Inp glbl                                 |          1.35  |
# | swedencentral | gpt4omini-rt-txt1217 Inp glbl               |          0.6   |
# | swedencentral | o1 preview cached input regnl               |          9.075 |
# | swedencentral | gpt 4o 0806 cached Inp regnl                |          1.513 |
# | swedencentral | Kontext Pro Dzone                           |      44000     |
# | swedencentral | MAI-DS-R1 Inp Dzone                         |          1.485 |
# | swedencentral | gpt 4o 1120 Inp Data Zone                   |          2.75  |
# | swedencentral | o1 preview output Data Zone                 |         66     |
# | swedencentral | gpt-4o-aud-1217 Inp glbl                    |         40     |
# | swedencentral | file-search-tool-calls-rgnl                 |       3025     |
# | swedencentral | Embed v3 DZ                                 |          0.517 |
# | swedencentral | gpt-4-turbo-128K Output-regional            |         36.3   |
# | swedencentral | gpt4omini-aud1217-txt Inp DZone             |          0.165 |
# | swedencentral | Grok 10 Outp glbl                           |          0.5   |
# | swedencentral | OCR 1125 Dzone                              |       2200     |
# | swedencentral | gpt 4o 0513 Output global                   |         15     |
# | swedencentral | o1 Batch Outp Data Zone                     |         33     |
# | swedencentral | o1 preview input Data Zone                  |         16.5   |
# | swedencentral | gpt-4o-mini-transcribe-aud-inp-rgnl         |          3.63  |
# | swedencentral | gpt-4o-transcribe-txt-inp-rgnl              |          3.025 |
# | swedencentral | o1 Batch Inp glbl                           |          7.5   |
# | swedencentral | gpt-4.1-nano-ft input regional              |          0.121 |
# | swedencentral | gpt 4o 0513 Input regional                  |          6.05  |
# | swedencentral | gpt 4.1 mini cached Inp regnl               |          0.121 |
# | swedencentral | gpt-4-Turbo-Batch-128K Inp-glbl             |          5     |
# | swedencentral | gpt-4o-mini-transcribe-txt-out-glbl         |          5     |
# | swedencentral | gpt-4o-rt-txt-1217 cchd Inp rgnl            |          3.025 |
# | swedencentral | gpt rt aud 0828 Outp DZone                  |         70.4   |
# | swedencentral | gpt-image-1-inp-img-dzone                   |         11     |
# | swedencentral | gpt-5-codex-ccchd-inp-glbl                  |          0.125 |
# | swedencentral | gpt 4o mini 0718 cached Inp Data Zone       |          0.083 |
# | swedencentral | gpt-4.1-mini-ft cached input regnl          |          0.121 |
# | swedencentral | o3-mini-ft model grader input               |          1.21  |
# | swedencentral | gpt 41 mn pp inp dz                         |          0.77  |
# | swedencentral | gpt img 1 mini inp cchd txt dzone           |          0.22  |
# | swedencentral | o1 mini Batch Inp Data Zone                 |          0.605 |
# | swedencentral | gpt-4o-mini-0718-FT-Trng-regnl              |          3.3   |
# | swedencentral | gpt-4o-mini-0718-cached-FT-inp-regnl        |          0.091 |
# | swedencentral | gpt4omini-rt-txt1217 Outp DZone             |          2.64  |
# | swedencentral | gpt 4.1 cached Inp glbl                     |          0.5   |
# | swedencentral | gpt4omini-aud1217-txt Outp DZone            |          0.66  |
# | swedencentral | Phi-3.5-Mini-Instruct-Finetuned             |          3     |
# | swedencentral | Model 2 Inp DZ                              |          0.66  |
# | swedencentral | Qwen3 32B-Out-FT                            |          1.2   |
# | swedencentral | gpt-4.1-dev-ft inpt glbl                    |          2     |
# | swedencentral | Grok-3 Mini Outp Dzone                      |          1.38  |
# | swedencentral | Large 3 Outp Dzone                          |          1.65  |
# | swedencentral | Mistral model 1-IN-FT                       |          0.05  |
# | swedencentral | gpt4omini-rt-txt1217 Inp DZone              |          0.66  |
# | swedencentral | o4-mini 0416 Batch Inp Data Zone            |          0.605 |
# | swedencentral | gpt aud 0828 txt Outp glbl                  |         10     |
# | swedencentral | gpt-image-1-output-img-dzone                |         44     |
# | swedencentral | o4-mini 0416 Outp glbl                      |          4.4   |
# | swedencentral | gpt-4o-mini-0718-cached-FT-inp-glbl         |          0.075 |
# | swedencentral | gpt-4o-aud-1217-txt Outp DZone              |         11     |
# | swedencentral | R3 Outp DZone                               |          4.94  |
# | swedencentral | gpt4omini-rt-txt1217 Inp regnl              |          0.726 |
# | swedencentral | gpt rt txt mini Outp glbl                   |          2.4   |
# | swedencentral | gpt 4o 1120 Inp glbl                        |          2.5   |
# | swedencentral | gpt-4o-aud-1217 Outp glbl                   |         80     |
# | swedencentral | o1 mini input regnl                         |          1.331 |
# | swedencentral | gpt-4o-mini-ft model grader output          |          0.66  |
# | swedencentral | codex mini out dzone                        |          6.6   |
# | swedencentral | gpt-4.1-mini-ft input regional              |          0.484 |
# | swedencentral | gpt-4o-aud-1217-txt Inp DZone               |          2.75  |
# | swedencentral | V3.2 SP Inp glbl                            |          0.58  |
# | swedencentral | gpt-4o-mini-transcribe-aud-inp-glbl         |          3     |
# | swedencentral | gpt-4o-rt-aud-0603 cchd Inp DZn             |          2.75  |
# | swedencentral | Phi-3.5-MoE-Instruct-Output                 |          0.64  |
# | swedencentral | gpt-4.1-nano-ft cached input regnl          |          0.031 |
# | swedencentral | gpt-4.1-mini-ft output global               |          1.6   |
# | swedencentral | Embed v4 DZ                                 |          0.132 |
# | swedencentral | o3 mini 0131 output Data Zone               |          4.84  |
# | swedencentral | V3-0324 Inp DZone                           |          1.25  |
# | swedencentral | Grok-3 Mini Inp glbl                        |          0.25  |
# | swedencentral | o4-mini 0416 Batch Outp glbl                |          2.2   |
# | swedencentral | gpt 5 pro out dzone                         |        132     |
# | swedencentral | gpt-4o-mini-transcribe-txt-inp-dz           |          1.375 |
# | swedencentral | gpt-4.1-mini-dev-ft cchd inpt glbl          |          0.1   |
# | swedencentral | gpt4omini-rt-aud1217 cchd Inp glbl          |          0.3   |
# | swedencentral | Flux 1.1 Pro Dzone                          |      44000     |
# | swedencentral | Grok-3 Mini Inp regnl                       |          0.3   |
# | swedencentral | gpt-4o-rt-aud-1217 Inp DZone                |         44     |
# | swedencentral | o3-pro Inp Data Zone                        |          0.75  |
# | swedencentral | Flux 1.1 Pro regnl                          |      48400     |
# | swedencentral | gpt-4o-rt-aud-1217 Inp regnl                |         48.4   |
# | swedencentral | gpt-4o-transcribe-txt-inp-dz                |          2.75  |
# | swedencentral | Phi-3-Small-128K-Instruct-Input             |          0.15  |
# | swedencentral | gpt-4o-rt-aud-0603 Outp DZone               |         88     |
# | swedencentral | gpt-4-turbo128K Inp-glbl                    |         10     |
# | swedencentral | codex mini inp cchd glbl                    |          0.375 |
# | swedencentral | gpt4omini-rt-aud1217 cchd Inp rgnl          |          0.363 |
# | swedencentral | gpt4o realtimePrvwTxtOutp DataZone          |         22     |
# | swedencentral | Phi-3.5-MoE-Instruct-Output-FT              |          0.64  |
# | swedencentral | gpt-35-turbo-16k-Output-regional            |          4     |
# | swedencentral | Phi-3-Mini-4K-Instruct-Input                |          0.13  |
# | swedencentral | Kontext Pro regnl                           |      48400     |
# | swedencentral | gpt img 1 mini inp img glbl                 |          2.5   |
# | swedencentral | V3.2 SP Inp DZ                              |          0.64  |
# | swedencentral | o3 mini 0131 Batch Outp glbl                |          2.2   |
# | swedencentral | Phi-3-Medium-128K-Instruct-Input            |          0.17  |
# | swedencentral | o3-pro Batch Outp Data Zone                 |         12.5   |
# | swedencentral | gpt-4-Turbo-Batch-128K Outp-glbl            |         15     |
# | swedencentral | gpt rt txt 0828 Inp DZone                   |          4.4   |
# | swedencentral | Large 3 Outp glbl                           |          1.5   |
# | swedencentral | V3.2 Outp DZ                                |          1.85  |
# | swedencentral | gpt img 1 mini out img glbl                 |          8     |
# | swedencentral | gpt-4.1-dev-ft cchd inpt glbl               |          0.5   |
# | swedencentral | gpt-4-8K-Batch-Inp-glbl                     |         15     |
# | swedencentral | gpt-4o-0806-FT-outp-regnl                   |         11     |
# | swedencentral | gpt 4o 0513 Batch Inp Data Zone             |          2.75  |
# | swedencentral | Model 2 Outp glbl                           |          3     |
# | swedencentral | gpt4o realtimePrvwTxtInp DataZone           |          5.5   |
# | swedencentral | Grok 6 Outp glbl                            |          0.5   |
# | swedencentral | Phi-4-Mini-Output                           |          0.3   |
# | swedencentral | o3 mini 0131 output regnl                   |          5.324 |
# | swedencentral | gpt-4o-mini-transcribe-txt-inp-glbl         |          1.25  |
# | swedencentral | o3-pro Inp regnl                            |          1.5   |
# | swedencentral | gpt-4o-mini-tts-aud-out-glbl                |         12     |
# | swedencentral | gpt 4.1 nano Batch Inp glbl                 |          0.05  |
# | swedencentral | gpt 4.1 nano cached Inp regnl               |          0.031 |
# | swedencentral | gpt-4o-ft model grader cched inpt           |          1.375 |
# | swedencentral | Rerank v4 Fast DZ                           |       2200     |
# | swedencentral | gpt 4o 1120 cached Inp Data Zone            |          1.375 |
# | swedencentral | gpt aud mini txt Outp glbl                  |          2.4   |
# | swedencentral | gpt-4o-mini-0718-Outp-glbl                  |          0.6   |
# | swedencentral | Model 2 Inp glbl                            |          0.6   |
# | swedencentral | gpt-image-1-inp-cached-txt-rgnl             |          1.513 |
# | swedencentral | gpt 4o 0513 Input Data Zone                 |          5.5   |
# | swedencentral | o3 0416 Inp regnl                           |          2.42  |
# +---------------+---------------------------------------------+----------------+

# %% [markdown]
# <a id='4'></a>
# ### 4️⃣ Load the pricing data into Azure Monitor custom table
#
# 👉 This script uses retail price information. Please adjust it to apply a discount or to use a flat rate with PTUs.
# 👉 We are multiplying by 1000 to get the retail price per 1K tokens.
# 👉 Deploy this script as a [job](https://learn.microsoft.com/en-us/azure/container-apps/jobs?tabs=azure-cli) to run automatically on a predefined schedule.

# %%
import requests
from azure.identity import DefaultAzureCredential
from azure.monitor.ingestion import LogsIngestionClient
from azure.core.exceptions import HttpResponseError
from datetime import datetime, timezone

credential = DefaultAzureCredential()
client = LogsIngestionClient(endpoint=pricing_dcr_endpoint, credential=credential, logging_enable=False)

for aiservice in aiservices_config:
    aiservice_resource_location = aiservice['location']
    prices = requests.get(f"https://prices.azure.com/api/retail/prices?currencyCode='{currency_code}'&$filter=serviceName eq 'Foundry Models' and unitOfMeasure eq '1K' and armRegionName eq '{aiservice_resource_location}'")    
    new_prices = requests.get(f"https://prices.azure.com/api/retail/prices?currencyCode='{currency_code}'&$filter=serviceName eq 'Foundry Models' and unitOfMeasure eq '1M' and armRegionName eq '{aiservice_resource_location}'")
    
    if prices.status_code == 200 and new_prices.status_code == 200:
        prices_json = prices.json()
        new_prices_json = new_prices.json()
        
        if prices_json and 'Items' in prices_json and new_prices_json and 'Items' in new_prices_json:
            for deployment in models_config:
                model_name = deployment.get("name")
                
                # Try to find price in new_prices (1M) first - use without multiplying by 1000
                input_tokens_price = next((item['retailPrice'] for item in new_prices_json['Items'] if item.get('skuName') == deployment.get("inputTokensMeterSku")), None)
                output_tokens_price = next((item['retailPrice'] for item in new_prices_json['Items'] if item.get('skuName') == deployment.get("outputTokensMeterSku")), None)
                
                price_source = "1M"
                
                # If not found in new_prices, fallback to prices (1K) and multiply by 1000
                if input_tokens_price is None:
                    input_tokens_price = next((item['retailPrice'] * 1000 for item in prices_json['Items'] if item.get('skuName') == deployment.get("inputTokensMeterSku")), None)
                    price_source = "1K"
                
                if output_tokens_price is None:
                    output_tokens_price = next((item['retailPrice'] * 1000 for item in prices_json['Items'] if item.get('skuName') == deployment.get("outputTokensMeterSku")), None)
                    price_source = "1K"
                
                utils.print_info(f"Adding model {model_name} (source: {price_source}) with input / output tokens price {input_tokens_price} / {output_tokens_price}")
                body = [{ "TimeGenerated": str(datetime.now(timezone.utc)),
                        "Model": model_name,
                        "InputTokensPrice": input_tokens_price,
                        "OutputTokensPrice": output_tokens_price }]
                try:
                    client.upload(rule_id=pricing_dcr_immutable_id, stream_name=pricing_dcr_stream, logs=body)
                    utils.print_ok(f"Upload succeeded for model {model_name}")
                except HttpResponseError as e:
                    utils.print_error(f"Upload failed: {e}")
# Out:
# 👉🏽 Adding model gpt-5.2-chat (source: 1M) with input / output tokens price 1.75 / 14.0
# ✅ Upload succeeded for model gpt-5.2-chat ⌚ 00:44:35.418197
# 👉🏽 Adding model gpt-5.2 (source: 1M) with input / output tokens price 1.75 / 14.0
# ✅ Upload succeeded for model gpt-5.2 ⌚ 00:44:35.716265
# 👉🏽 Adding model gpt-5-mini (source: 1M) with input / output tokens price 0.25 / 2.0
# ✅ Upload succeeded for model gpt-5-mini ⌚ 00:44:36.046444
# 👉🏽 Adding model gpt-5-nano (source: 1M) with input / output tokens price 0.05 / 0.4
# ✅ Upload succeeded for model gpt-5-nano ⌚ 00:44:36.337245
# 👉🏽 Adding model gpt-4.1-mini (source: 1K) with input / output tokens price 0.4 / 1.6
# ✅ Upload succeeded for model gpt-4.1-mini ⌚ 00:44:36.671425
# 👉🏽 Adding model gpt-4.1 (source: 1K) with input / output tokens price 2.0 / 8.0
# ✅ Upload succeeded for model gpt-4.1 ⌚ 00:44:36.940211
# 👉🏽 Adding model DeepSeek-V3.2 (source: 1K) with input / output tokens price 0.58 / 1.6800000000000002
# ✅ Upload succeeded for model DeepSeek-V3.2 ⌚ 00:44:37.256189

# %% [markdown]
# <a id='5'></a>
# ### 5️⃣ Load the Subscription Quota into Azure Monitor custom table

# %%
import requests
from azure.identity import DefaultAzureCredential
from azure.monitor.ingestion import LogsIngestionClient
from azure.core.exceptions import HttpResponseError
from datetime import datetime, timezone

credential = DefaultAzureCredential()
client = LogsIngestionClient(endpoint=subscription_quota_dcr_endpoint, credential=credential, logging_enable=False)

for subscription in apim_subscriptions_config:
    for product in apim_products_config:
        if product.get("name") == subscription.get("product"):
            cost_quota = product.get("costQuota")
            utils.print_info(f"Adding {subscription.get('name')} with cost quota {cost_quota}")
            body = [{ 
                "TimeGenerated": str(datetime.now(timezone.utc)),
                "Subscription": subscription.get("name"),
                "Email": subscription.get("email"),
                "CostQuota": cost_quota
            }]
            try:
                client.upload(rule_id=subscription_quota_dcr_immutable_id, stream_name=subscription_quota_dcr_stream, logs=body)
                utils.print_ok(f"Upload succeeded for {subscription.get("name")}")
            except HttpResponseError as e:
                utils.print_error(f"Upload failed: {e}")
# Out:
# 👉🏽 Adding subscription1 with cost quota 15
# ✅ Upload succeeded for subscription1 ⌚ 00:54:24.589905
# 👉🏽 Adding subscription2 with cost quota 10
# ✅ Upload succeeded for subscription2 ⌚ 00:54:24.928378
# 👉🏽 Adding subscription3 with cost quota 5
# ✅ Upload succeeded for subscription3 ⌚ 00:54:25.257599
# 👉🏽 Adding subscription4 with cost quota 5
# ✅ Upload succeeded for subscription4 ⌚ 00:54:25.588795

# %% [markdown]
# <a id='sdk'></a>
# ### 🧪 Execute multiple runs using the Azure OpenAI Python SDK
#
# 👉 We will send requests with random subscription and models. Adjust the `sleep_time_ms` and the number of `runs` to your test scenario.
#
# Use test.http to send request.

# %% [markdown]
# <a id='workbooks'></a>
# ### 🔍 Open the dashboard and workbooks in the Azure Portal
#
# 👉 The Cost Analysis workbook contains information on the total costs and quotas for each subscription.
# 👉 The [Azure OpenAI Insights workbook](https://github.com/dolevshor/Azure-OpenAI-Insights) provides comprehensive details about service and model usage. Credits to [Dolev Shor](https://github.com/dolevshor/Azure-OpenAI-Insights).
# 👉 The [Alerts workbook](https://github.com/microsoft/AzureMonitorCommunity/tree/master/Azure%20Services) provides information about the alerts triggered by Azure Monitor.

# %% [markdown]
# <a id='clean'></a>
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.
#
# Use `azd down` to remove all resources.
